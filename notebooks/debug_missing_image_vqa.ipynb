# %%
# !python ../src/debug_missing_vqa.py \
  --image-ids-file ../data/vqa_rerun_missing/missing_image_ids.txt \
  --output-dir ../data/vqa_rerun_missing/debug_run2 \
  --qtypes-per-image 0 \
  --device cpu
# Out:
# [KGRetriever] Loading intfloat/multilingual-e5-small on cpu...
# [KGRetriever] Ready.
#
# [WARN] substitution_rules is disabled because fromIngredient/toIngredient embeddings are missing.
# Loaded 1371 dishes from Neo4j
# Embedded relationships: 5710
# Question types: ingredients, cooking_technique, flavor_profile, origin_locality, allergen_restrictions, dietary_restrictions, ingredient_category, food_pairings, dish_classification
# Target image ids: 229
# Questions per qtype: 1
# Fetched image rows from Supabase: 229
#   ✓ image000029::ingredient_category::1 -> A | Xét về nhóm thực phẩm chính, món ăn nằm ở góc dưới bên trái của khay gỗ thuộc nhóm nào, và
#   ✓ image000029::dietary_restrictions::1 -> B | Trong số các món ăn được bày trên khay gỗ, món nằm ở góc dưới bên trái có phù hợp với chế
#   ✓ image000029::allergen_restrictions::1 -> C | Nếu một thực khách bị dị ứng với các loài giáp xác, họ nên tránh món ăn nào đang được đặt
#   ✓ image000128::allergen_restrictions::1 -> B | Trong mâm cơm này, món ăn có màu cam đỏ rực rỡ nằm ở phía dưới bên trái có thể gây nguy cơ
#   ✓ image000128::ingredient_category::1 -> B | Dựa vào vị trí của các món ăn trên mâm đồng, món ăn có màu cam đỏ rực rỡ nằm ở góc dưới bê
#   ✓ image000128::dietary_restrictions::1 -> B | Xét đĩa thức ăn có màu cam đỏ rực rỡ nằm ở phía dưới bên trái của mâm đồng, món ăn này có
#   ✓ image000150::dietary_restrictions::1 -> B | Nếu xét món ăn nằm ở góc dưới bên trái khay gỗ, liệu món này có phù hợp với người ăn chay
#   ✓ image000150::ingredient_category::1 -> C | Xét món ăn nằm ở góc dưới bên trái của khay gỗ, nếu phân loại nguyên liệu chính của món nà
#   ✓ image000150::allergen_restrictions::1 -> B | Xét vị trí của món ăn nằm ở góc dưới bên trái khay gỗ, nếu một người bị dị ứng với nhóm th
#   ✓ image000247::cooking_technique::1 -> B | Món ăn nằm ở vị trí cao nhất trên bàn gỗ có màu nâu sẫm được chế biến bằng phương pháp nào
#   ✓ image000294::ingredient_category::1 -> B | Món ăn nằm ở vị trí góc trên bên trái của mâm cơm thuộc nhóm thực phẩm nào dựa trên phân l
#   ✓ image000294::allergen_restrictions::1 -> C | Nếu một thực khách bị dị ứng với các loài giáp xác, người đó nên tránh món ăn nào đang đượ
#   ✓ image000294::dietary_restrictions::1 -> B | Trong mâm cơm này, nếu một người thực hiện chế độ ăn thuần thực vật chỉ được phép dùng các
#   ✓ image000298::dietary_restrictions::1 -> B | Xét đĩa thức ăn nằm ở góc dưới bên phải khay gỗ, món ăn này có phù hợp với người đang thực
#   ✓ image000298::allergen_restrictions::1 -> B | Nằm ở góc dưới bên phải khay gỗ là món ăn được cuốn bằng rau xanh, tôm và thịt. Đối với mộ
#   ✓ image000298::ingredient_category::1 -> B | Khi quan sát khay gỗ, nếu xét món ăn nằm ở góc dưới bên phải so với đĩa salad rau mầm, nhó
#   ✓ image000357::ingredient_category::1 -> B | Nhìn vào chiếc mẹt, món ăn nằm trong thố sứ có màu vàng nâu được đặt ở vị trí trung tâm ph
#   ✓ image000466::dietary_restrictions::1 -> B | Xét trên mâm gỗ tròn, món ăn nằm ở vị trí dưới cùng có màu cam đỏ bóng bẩy liệu có phù hợp
#   ✓ image000466::ingredient_category::1 -> B | Dựa vào vị trí nằm dưới cùng của mâm gỗ, món ăn có màu cam đỏ bóng bẩy thuộc nhóm thực phẩ
#   ✓ image000466::allergen_restrictions::1 -> A | Nếu một thực khách bị dị ứng với các loài động vật có vỏ, họ nên tránh món ăn nào nằm ở vị
#   ✓ image000569::dietary_restrictions::1 -> B | Trong mâm cơm này, món ăn nào nằm ở vị trí phía dưới cùng của khung hình là lựa chọn không
#   ✓ image000569::ingredient_category::1 -> A | Trong mâm cơm này, món ăn được xếp vòng tròn ở phía dưới cùng thuộc nhóm thực phẩm nào và
#   ✓ image000569::allergen_restrictions::1 -> B | Trong mâm cơm này, món ăn được xếp vòng tròn ở phía dưới cùng có chứa thành phần gây dị ứn
#   ✓ image000614::allergen_restrictions::1 -> C | Nếu một thực khách bị dị ứng với các loài động vật có vỏ, họ nên tránh những món ăn nào kh
#   ✓ image000614::ingredient_category::1 -> B | Xét món ăn nằm ở góc trên bên trái so với món ăn ở góc dưới bên phải, nhóm thực phẩm chính
#   ✓ image000614::dietary_restrictions::1 -> B | Trong bốn món ăn được sắp xếp trong khung hình, món nằm ở góc trên bên trái có đặc điểm di
#   ✓ image000638::allergen_restrictions::1 -> B | Món ăn có màu cam đỏ bóng bẩy nằm ở vị trí trung tâm bàn gỗ có khả năng gây dị ứng cho nhó
#   ✓ image000638::dietary_restrictions::1 -> B | Trong số các món ăn trên bàn, món nằm ở vị trí trung tâm có màu cam đỏ bóng bẩy và món nằm
#   ✓ image000638::ingredient_category::1 -> A | Nhìn vào bàn ăn, món nằm ở vị trí trung tâm có màu cam đỏ bóng bẩy thuộc nhóm thực phẩm nà
#   ✓ image000709::dish_classification::1 -> A | Trong mâm cơm này, món ăn nào được phân loại là món chính tinh bột nằm ở vị trí cao nhất v
#   ✓ image000715::allergen_restrictions::1 -> B | Trong hộp thức ăn nằm ở vị trí bên trái, món ăn có màu cam đỏ được đặt cùng với bào ngư và
#   ✓ image000715::ingredient_category::1 -> B | Trong hộp thức ăn nằm ở vị trí bên trái, xét nhóm thực phẩm chủ đạo của các nguyên liệu nh
#   ✓ image000715::dietary_restrictions::1 -> B | Trong hộp thức ăn nằm phía bên trái, món ăn có màu cam đỏ nằm ở vị trí đầu tiên có phù hợp
#   ✓ image000852::allergen_restrictions::1 -> B | Nếu một người bị dị ứng với các loại hải sản có vỏ, họ nên tránh món ăn nào đang được đặt
#   ✓ image000852::ingredient_category::1 -> C | Xét món ăn nằm ở góc dưới bên trái của khay mây tròn, món ăn này thuộc nhóm thực phẩm nào
#   ✓ image000852::dietary_restrictions::1 -> B | Trong số các món ăn được đặt trên khay mây tròn, món nằm ở góc dưới bên trái có phù hợp vớ
#   ✓ image000858::dietary_restrictions::1 -> B | Xét về chế độ ăn uống, món chính đặt trên mẹt tre có màu cam đỏ với các vết cháy sém nằm ở
#   ✓ image000858::allergen_restrictions::1 -> B | Đối với thực khách đang ngồi trước mẹt tre này, món ăn chính màu cam đỏ có vết cháy sém nằ
#   ✓ image000858::ingredient_category::1 -> B | Nhìn vào mẹt tre, thành phần chính nằm ở trung tâm có màu cam đỏ với các vết cháy sém thuộ
#   ✓ image000932::cooking_technique::1 -> B | Xét các món ăn trên bàn, món nằm ở góc trên bên trái có màu cam đỏ rực rỡ và món nằm ở góc
#   ✓ image000932::ingredient_category::1 -> B | Xét về nhóm thực phẩm chính, món ăn nằm ở góc trên bên trái so với hai chén nước chấm ở tr
#   ✓ image000932::allergen_restrictions::1 -> C | Nếu một thực khách có cơ địa dị ứng với nhóm hải sản giáp xác, họ nên tránh món ăn nào đan
#   ✓ image000977::dietary_restrictions::1 -> B | Khi quan sát mâm cơm trên nền mây tre đan, món ăn nằm ở góc trên bên trái có phù hợp với c
#   ✓ image000977::ingredient_category::1 -> C | Món ăn nằm ở góc trên bên trái mâm cơm thuộc nhóm thực phẩm nào, xét trong mối tương quan
#   ✓ image001121::dietary_restrictions::1 -> C | Xét món ăn chính nằm ở trung tâm đĩa và bát canh bầu ở góc trên bên trái, món nào trong số
#   ✓ image001121::ingredient_category::1 -> B | Dựa vào vị trí trung tâm của đĩa thức ăn chính và bát canh bầu ở góc trên bên trái, nhóm t
#   ✓ image001121::allergen_restrictions::1 -> A | Đối với người có cơ địa dị ứng với loại thực phẩm thuộc nhóm giáp xác, việc lựa chọn món ă
#   ✓ image001235::allergen_restrictions::1 -> B | Trong ba món ăn trên bàn, món nằm ở vị trí phía dưới có khả năng gây dị ứng cho người nhạy
#   ✓ image001235::dietary_restrictions::1 -> A | Trong ba món ăn trên bàn, món nằm ở vị trí phía dưới có đặc điểm gì về chế độ ăn uống khi
#   ✓ image001235::ingredient_category::1 -> C | Khi quan sát đĩa thức ăn có màu cam đỏ đậm nằm ở phía dưới so với tô canh bí xanh ở góc tr
#   ✓ image001238::ingredient_category::1 -> A | Trong số các món ăn trên bàn, món nằm ở vị trí trên cùng có thành phần chính thuộc nhóm th
#   ✓ image001238::allergen_restrictions::1 -> B | Trong số các món ăn trên bàn, món nằm ở vị trí cao nhất trên nền xà lách xanh có thể gây r
#   ✓ image001238::dietary_restrictions::1 -> B | Trong số các món ăn trên bàn, xét đĩa nằm ở vị trí trên cùng và đĩa nằm ở góc dưới bên trá
#   ✓ image001403::dish_classification::1 -> B | Trong bố cục vòng tròn của bữa ăn, món ăn nào được phân loại là món chính cung cấp tinh bộ
#   ✓ image001487::dish_classification::1 -> B | Dựa vào hình ảnh, món ăn chính nằm ở trung tâm chiếc nồi đất có màu sắc rực rỡ và độ bão h
#   ✓ image001624::ingredient_category::1 -> B | Xét đĩa thức ăn nằm ở phía bên trái bàn gỗ và bát canh ở phía trên bên phải, hãy cho biết
#   ✓ image001669::dietary_restrictions::1 -> B | Trong mâm cơm ở phần giữa, món tôm xào súp lơ nằm ở trung tâm có phù hợp với chế độ ăn thu
#   ✓ image001669::ingredient_category::1 -> A | Trong phần giữa của hình ảnh, món tôm xào súp lơ nằm ở vị trí trung tâm có thuộc nhóm thực
#   ✓ image001669::allergen_restrictions::1 -> C | Trong số các món ăn ở phần giữa của hình ảnh, cụ thể là món nằm ở vị trí trung tâm, người
#   ✓ image001761::dish_classification::1 -> C | Trong các món ăn được bày trên bàn, món nào thuộc nhóm món kho và vị trí của nó nằm ở đâu
#   ✓ image001870::ingredient_category::1 -> B | Trong chiếc mẹt tre này, món ăn nằm ở vị trí phía dưới cùng thuộc nhóm thực phẩm nào và mó
#   ✓ image001926::cooking_technique::1 -> C | Tại góc trên bên trái của bức ảnh là món ăn có màu nâu sẫm, khi so sánh với món cánh gà nư
#   ✓ image001939::dish_classification::1 -> B | Dựa vào cách bài trí trên bàn ăn, món ăn nào nằm ở góc dưới bên phải và thuộc nhóm món nướ
#   ✓ image002295::dietary_restrictions::1 -> B | Nếu xét món ăn nằm ở góc trên bên phải của mẹt tre so với món ăn được bày ở phía dưới nó,
#   ✓ image002301::ingredient_category::1 -> C | Trong mâm cơm này, món ăn nằm ở phía trên cùng thuộc nhóm thực phẩm nào và món ăn nằm ở gó
#   ✓ image002301::ingredients::1 -> A | Khi quan sát mẹt thức ăn, nếu bạn muốn kết hợp một loại nguyên liệu tạo độ ngọt thanh tự n
#   ✓ image002304::dietary_restrictions::1 -> B | Xét chiếc mẹt tre đang bày biện các món ăn, món nằm ở vị trí phía trên cùng có màu cam đỏ
#   ✓ image002304::ingredient_category::1 -> A | Dựa trên vị trí của các món ăn trên mẹt tre, món nằm ở phía trên cùng thuộc nhóm thực phẩm
#   ✓ image002304::allergen_restrictions::1 -> B | Khi quan sát chiếc mẹt tre này, món ăn nằm ở vị trí cao nhất có màu cam đỏ bóng bẩy có thể
#
# -- Done --
# Attempted images: 229
# Generated samples: 69
# Debug rows: 1768
# Saved generated JSON: ..\data\vqa_rerun_missing\debug_run2\debug_generated_vqa.json
# Saved debug CSV: ..\data\vqa_rerun_missing\debug_run2\debug_failures.csv
#
# Top fail stages:
#   retrieve_empty: 1530
#   no_candidates: 210
#   no_anchor_dish: 28
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2215.94it/s]
# BertModel LOAD REPORT from: intfloat/multilingual-e5-small
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
import pandas as pd
from pathlib import Path

csv_path = Path("../data/vqa_rerun_missing/debug_run1/debug_failures.csv")
df = pd.read_csv(csv_path)

print("Tổng số debug rows:", len(df))
display(df["fail_stage"].value_counts().rename_axis("fail_stage").reset_index(name="count"))
# Out:
# Tổng số debug rows: 1114
#        fail_stage  count
# 0  retrieve_empty    918
# 1  no_anchor_dish    117
# 2   no_candidates     79

# %%
subset = df[df["fail_stage"] == "no_candidates"].copy()
display(subset.head(50))
# Out:
#         image_id                  qtype     fail_stage  \
# 175  image000247    ingredient_category  no_candidates
# 176  image000247        origin_locality  no_candidates
# 177  image000247   dietary_restrictions  no_candidates
# 178  image000247          food_pairings  no_candidates
# 179  image000247            ingredients  no_candidates
# 180  image000247  allergen_restrictions  no_candidates
# 181  image000247         flavor_profile  no_candidates
# 182  image000247    dish_classification  no_candidates
# 360  image000709    ingredient_category  no_candidates
# 361  image000709          food_pairings  no_candidates
# 362  image000709         flavor_profile  no_candidates
# 363  image000709  allergen_restrictions  no_candidates
# 364  image000709   dietary_restrictions  no_candidates
# 365  image000709        origin_locality  no_candidates
# 366  image000709      cooking_technique  no_candidates
# 367  image000709            ingredients  no_candidates
# 455  image000932         flavor_profile  no_candidates
# 456  image000932        origin_locality  no_candidates
# 457  image000932    ingredient_category  no_candidates
# 458  image000932            ingredients  no_candidates
# 459  image000932  allergen_restrictions  no_candidates
# 460  image000932          food_pairings  no_candidates
# 461  image000932   dietary_restrictions  no_candidates
# 462  image000932    dish_classification  no_candidates
# 631  image001391            ingredients  no_candidates
# 632  image001391   dietary_restrictions  no_candidates
# 633  image001391         flavor_profile  no_candidates
# 634  image001391    dish_classification  no_candidates
# 635  image001391  allergen_restrictions  no_candidates
# 636  image001391    ingredient_category  no_candidates
# 637  image001391        origin_locality  no_candidates
# 638  image001391          food_pairings  no_candidates
# 639  image001403         flavor_profile  no_candidates
# 640  image001403        origin_locality  no_candidates
# 641  image001403   dietary_restrictions  no_candidates
# 642  image001403  allergen_restrictions  no_candidates
# 643  image001403            ingredients  no_candidates
# 644  image001403      cooking_technique  no_candidates
# 645  image001403    ingredient_category  no_candidates
# 646  image001403          food_pairings  no_candidates
# 661  image001487            ingredients  no_candidates
# 662  image001487      cooking_technique  no_candidates
# 663  image001487         flavor_profile  no_candidates
# 664  image001487  allergen_restrictions  no_candidates
# 665  image001487        origin_locality  no_candidates
# 666  image001487    ingredient_category  no_candidates
# 667  image001487   dietary_restrictions  no_candidates
# 668  image001487          food_pairings  no_candidates
# 821  image001761        origin_locality  no_candidates
# 822  image001761      cooking_technique  no_candidates
#
#                                                 detail
# 175  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 176  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 177  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 178  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 179  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 180  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 181  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 182  anchor_dish=Cà Tím Kho; retrieved=1; filtered_...
# 360  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 361  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 362  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 363  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 364  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 365  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 366  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 367  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 455  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 456  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 457  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 458  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 459  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 460  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 461  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 462  anchor_dish=Cua Hấp; retrieved=1; filtered_row...
# 631  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 632  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 633  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 634  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 635  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 636  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 637  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 638  anchor_dish=Cá Rán; retrieved=1; filtered_rows...
# 639  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 640  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 641  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 642  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 643  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 644  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 645  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 646  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 661  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 662  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 663  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 664  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 665  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 666  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 667  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 668  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 821  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...
# 822  anchor_dish=Cơm Niêu; retrieved=1; filtered_ro...

# %%
subset = df[df["fail_stage"] == "no_anchor_dish"].copy()
display(subset)
# Out:
#          image_id qtype      fail_stage  \
# 9     image000006   NaN  no_anchor_dish
# 10    image000011   NaN  no_anchor_dish
# 11    image000014   NaN  no_anchor_dish
# 12    image000026   NaN  no_anchor_dish
# 40    image000055   NaN  no_anchor_dish
# ...           ...   ...             ...
# 1021  image002238   NaN  no_anchor_dish
# 1022  image002241   NaN  no_anchor_dish
# 1032  image002292   NaN  no_anchor_dish
# 1060  image002300   NaN  no_anchor_dish
# 1113  image002325   NaN  no_anchor_dish
#
#                                                  detail
# 9     food_items=['Bún chả', 'Bún', 'Chả nướng', 'Ra...
# 10    food_items=['Bún chả', 'Bún tươi', 'Chả nướng'...
# 11    food_items=['Bún bò Huế', 'Rau sống', 'Chanh',...
# 12    food_items=['Canh cua mồng tơi mướp', 'Đậu phụ...
# 40    food_items=['Vịt quay', 'Bún tươi', 'Bánh đa n...
# ...                                                 ...
# 1021  food_items=['Bánh khoái', 'Nước lèo', 'Rau sốn...
# 1022  food_items=['Bún bò Huế', 'Rau sống', 'Hành ng...
# 1032  food_items=['Cá basa kho', 'Canh bầu tôm', 'Cà...
# 1060  food_items=['Thịt heo xá xíu', 'Canh cua mồng ...
# 1113  food_items=['Thịt rang', 'Dưa chuột', 'Sô-cô-l...
#
# [117 rows x 4 columns]
